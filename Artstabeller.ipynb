# %% [markdown]
# # Artsdatabanken

# %%
import pandas as pd

# %%
url = "https://nortaxa.artsdatabanken.no/api/v1/DataTransfer/Export?scientificNameId=-1&includeSynonyms=true&includeVernacularNames=true&exportType=Csv"
biota =pd.read_csv(url, sep = ";", na_values = "NaN",dtype ="str")
#url = 'https://nortaxa.artsdatabanken.no/api/v1/DataTransfer/Export?scientificNameId=99480&includeSynonyms=true&includeVernacularNames=true&exportType=Csv'
#'blob:https://nortaxa.artsdatabanken.no/3f6d6c4f-5312-4d12-8624-a99c2272afb8'

# %%
display(biota)
# Out:
#        VernacularNameBokmaal StatusBokmaal        ReferenceBokmaal  \
# 0                        NaN           NaN                     NaN
# 1                  dyreriket     Preferred  CatalogueOfLife2008rev
# 2              erkebakterier     Preferred                     NaN
# 3                  bakterier     Preferred                     NaN
# 4             det gule riket     Preferred  CatalogueOfLife2008rev
# ...                      ...           ...                     ...
# 226308                   NaN           NaN                     NaN
# 226309                   NaN           NaN                     NaN
# 226310                   NaN           NaN                     NaN
# 226311                   NaN           NaN                     NaN
# 226312                   NaN           NaN                     NaN
#
#        CommentBokmaal ValidFromBokmaal VernacularNameNynorsk StatusNynorsk  \
# 0                 NaN              NaN                   NaN           NaN
# 1                 NaN       07.02.2012             dyreriket     Preferred
# 2                 NaN       02.02.2012                   NaN           NaN
# 3                 NaN       02.02.2012                   NaN           NaN
# 4                 NaN       02.02.2012        det gule riket     Preferred
# ...               ...              ...                   ...           ...
# 226308            NaN              NaN                   NaN           NaN
# 226309            NaN              NaN                   NaN           NaN
# 226310            NaN              NaN                   NaN           NaN
# 226311            NaN              NaN                   NaN           NaN
# 226312            NaN              NaN                   NaN           NaN
#
#        ReferenceNynorsk CommentNynorsk ValidFromNynorsk  ...  \
# 0                   NaN            NaN              NaN  ...
# 1                   NaN            NaN       07.02.2012  ...
# 2                   NaN            NaN              NaN  ...
# 3                   NaN            NaN              NaN  ...
# 4                   NaN            NaN       02.02.2012  ...
# ...                 ...            ...              ...  ...
# 226308              NaN            NaN              NaN  ...
# 226309              NaN            NaN              NaN  ...
# 226310              NaN            NaN              NaN  ...
# 226311              NaN            NaN              NaN  ...
# 226312              NaN            NaN              NaN  ...
#
#                         PresentationName     Rank TaxonomicStatus  \
# 0                                  Biota   Sphere        Accepted
# 1                               Animalia  Kingdom        Accepted
# 2                                Archaea  Kingdom        Accepted
# 3                               Bacteria  Kingdom        Accepted
# 4                              Chromista  Kingdom        Accepted
# ...                                  ...      ...             ...
# 226308                     Moniliformida    Order        Accepted
# 226309              Oligacanthorhynchida    Order        Accepted
# 226310             Oligacanthorhynchidae   Family        Accepted
# 226311               Macracanthorhynchus    Genus        Accepted
# 226312  Macracanthorhynchus hirudinaceus  Species        Accepted
#
#        NomenclaturalStatuses             NameString          Author  \
# 0                        NaN                  Biota             NaN
# 1                        NaN               Animalia             NaN
# 2                        NaN                Archaea             NaN
# 3                        NaN               Bacteria             NaN
# 4                        NaN              Chromista      Caval.-Sm.
# ...                      ...                    ...             ...
# 226308                   NaN          Moniliformida             NaN
# 226309                   NaN   Oligacanthorhynchida             NaN
# 226310                   NaN  Oligacanthorhynchidae             NaN
# 226311                   NaN    Macracanthorhynchus             NaN
# 226312                   NaN           hirudinaceus  (Pallas, 1781)
#
#                      Reference   ValidFrom                            Comment  \
# 0                          NaN  01.01.2008                              Biota
# 1       CatalogueOfLife2008rev  30.04.2009  Importert fra "Catalogue of Life"
# 2       CatalogueOfLife2008rev  30.04.2009  Importert fra "Catalogue of Life"
# 3       CatalogueOfLife2008rev  30.04.2009  Importert fra "Catalogue of Life"
# 4                          NaN  30.04.2009                                NaN
# ...                        ...         ...                                ...
# 226308  CatalogueOfLife2008rev  30.04.2009  Importert fra "Catalogue of Life"
# 226309  CatalogueOfLife2008rev  30.04.2009  Importert fra "Catalogue of Life"
# 226310                     NaN  08.11.2012                                NaN
# 226311                     NaN  08.11.2012                                NaN
# 226312                     NaN  28.01.2015                                NaN
#
#        ExistsInNorway
# 0               False
# 1               False
# 2               False
# 3               False
# 4               False
# ...               ...
# 226308          False
# 226309          False
# 226310          False
# 226311          False
# 226312           True
#
# [226313 rows x 53 columns]

# %%
url = 'https://nortaxa.artsdatabanken.no/api/v1/DataTransfer/Export?scientificNameId=99480&includeSynonyms=true&includeVernacularNames=true&exportType=Csv'
#url = "https://nortaxa.artsdatabanken.no/api/v1/DataTransfer/Export?scientificNameId=-1&includeSynonyms=true&includeVernacularNames=true&exportType=Csv"
biota =pd.read_csv(url, sep = ";", na_values = "NaN",dtype ="str")
biota
# Out:
#     VernacularNameBokmaal StatusBokmaal ReferenceBokmaal CommentBokmaal  \
# 0          orkidéfamilien     Preferred              NaN            NaN
# 1      narrmarihandslekta     Preferred              NaN            NaN
# 2          skogfrueslekta     Preferred              NaN            NaN
# 3        fjellkurleslekta     Preferred              NaN            NaN
# 4        grønnkurleslekta     Preferred              NaN            NaN
# ..                    ...           ...              ...            ...
# 375         stor skogfrue     Preferred              NaN            NaN
# 376          narrmarihand     Preferred              NaN            NaN
# 377             salepsrot     Preferred              NaN            NaN
# 378                   NaN           NaN              NaN            NaN
# 379           myrmarihand     Preferred              NaN            NaN
#
#     ValidFromBokmaal VernacularNameNynorsk StatusNynorsk ReferenceNynorsk  \
# 0         13.09.2009        orkidéfamilien     Preferred              NaN
# 1         13.09.2009    narrmarihandslekta     Preferred              NaN
# 2         13.09.2009        skogfrueslekta     Preferred              NaN
# 3         13.09.2009      fjellkurleslekta     Preferred              NaN
# 4         13.09.2009       grønkurleslekta     Preferred              NaN
# ..               ...                   ...           ...              ...
# 375       03.07.2018         stor skogfrue     Preferred              NaN
# 376       13.09.2009          narrmarihand     Preferred              NaN
# 377       03.07.2018             salepsrot     Preferred              NaN
# 378              NaN                   NaN           NaN              NaN
# 379       03.07.2018           myrmarihand     Preferred              NaN
#
#     CommentNynorsk ValidFromNynorsk  ...        PresentationName     Rank  \
# 0              NaN       13.09.2009  ...             Orchidaceae   Family
# 1              NaN       13.09.2009  ...              Anacamptis    Genus
# 2              NaN       13.09.2009  ...           Cephalanthera    Genus
# 3              NaN       13.09.2009  ...              Chamorchis    Genus
# 4              NaN       13.09.2009  ...            Coeloglossum    Genus
# ..             ...              ...  ...                     ...      ...
# 375            NaN       03.07.2018  ...   Cephalanthera pallens  Species
# 376            NaN       13.09.2009  ...        Anacamptis morio  Species
# 377            NaN       03.07.2018  ...  Anacamptis pyramidalis  Species
# 378            NaN              NaN  ...    Anacamptis laxiflora  Species
# 379            NaN       03.07.2018  ...    Anacamptis palustris  Species
#
#     TaxonomicStatus NomenclaturalStatuses     NameString  \
# 0          Accepted                   NaN    Orchidaceae
# 1          Accepted                   NaN     Anacamptis
# 2          Accepted                   NaN  Cephalanthera
# 3          Accepted                   NaN     Chamorchis
# 4          Accepted                   NaN   Coeloglossum
# ..              ...                   ...            ...
# 375         Synonym                   NaN        pallens
# 376        Accepted                   NaN          morio
# 377        Accepted                   NaN    pyramidalis
# 378        Accepted                   NaN      laxiflora
# 379        Accepted                   NaN      palustris
#
#                                         Author Reference   ValidFrom Comment  \
# 0                                        Juss.       NaN  20.08.2009     NaN
# 1                                        Rich.       NaN  20.08.2009     NaN
# 2                                        Rich.       NaN  20.08.2009     NaN
# 3                                        Rich.       NaN  20.08.2009     NaN
# 4                                       Hartm.       NaN  20.08.2009     NaN
# ..                                         ...       ...         ...     ...
# 375                                      Rich.       NaN  25.06.2016     NaN
# 376     (L.) R.M.Bateman, Pridgeon & M.W.Chase       NaN  24.06.2016     NaN
# 377                                 (L.) Rich.       NaN  24.06.2016     NaN
# 378   (Lam.) R.M.Bateman, Pridgeon & M.W.Chase       NaN  12.04.2018     NaN
# 379  (Jacq.) R.M.Bateman, Pridgeon & M.W.Chase       NaN  12.04.2018     NaN
#
#     ExistsInNorway
# 0            False
# 1            False
# 2            False
# 3            False
# 4            False
# ..             ...
# 375           True
# 376           True
# 377          False
# 378          False
# 379          False
#
# [380 rows x 53 columns]

# %%
#biota[pd.notna(biota['Species'])]
biota['Species']
# Out:
# 0              NaN
# 1              NaN
# 2              NaN
# 3              NaN
# 4              NaN
#           ...
# 375        pallens
# 376          morio
# 377    pyramidalis
# 378      laxiflora
# 379      palustris
# Name: Species, Length: 380, dtype: object

# %% [markdown]
# ## Nortaxa

# %%
import pandas as pd
artsnavnebase = "https://nortaxa.artsdatabanken.no/api/v1/DataTransfer/Export?scientificNameId=-1&includeSynonyms=true&includeVernacularNames=true&exportType=Csv"
artsnavnebase =pd.read_csv(artsnavnebase, sep = ";")
artsnavnebase.head
# Out:
# C:\Users\endofs\AppData\Local\Temp\ipykernel_12668\4147161154.py:3: DtypeWarning: Columns (7,8,12,19,20,22,23,24,26,27,28,30,31,33,34,37,38) have mixed types. Specify dtype option on import or set low_memory=False.
#   artsnavnebase =pd.read_csv(artsnavnebase, sep = ";")
# <bound method NDFrame.head of        VernacularNameBokmaal StatusBokmaal        ReferenceBokmaal  \
# 0                        NaN           NaN                     NaN
# 1                  dyreriket     Preferred  CatalogueOfLife2008rev
# 2              erkebakterier     Preferred                     NaN
# 3                  bakterier     Preferred                     NaN
# 4             det gule riket     Preferred  CatalogueOfLife2008rev
# ...                      ...           ...                     ...
# 226308                   NaN           NaN                     NaN
# 226309                   NaN           NaN                     NaN
# 226310                   NaN           NaN                     NaN
# 226311                   NaN           NaN                     NaN
# 226312                   NaN           NaN                     NaN
#
#        CommentBokmaal ValidFromBokmaal VernacularNameNynorsk StatusNynorsk  \
# 0                 NaN              NaN                   NaN           NaN
# 1                 NaN       07.02.2012             dyreriket     Preferred
# 2                 NaN       02.02.2012                   NaN           NaN
# 3                 NaN       02.02.2012                   NaN           NaN
# 4                 NaN       02.02.2012        det gule riket     Preferred
# ...               ...              ...                   ...           ...
# 226308            NaN              NaN                   NaN           NaN
# 226309            NaN              NaN                   NaN           NaN
# 226310            NaN              NaN                   NaN           NaN
# 226311            NaN              NaN                   NaN           NaN
# 226312            NaN              NaN                   NaN           NaN
#
#        ReferenceNynorsk CommentNynorsk ValidFromNynorsk  ...  \
# 0                   NaN            NaN              NaN  ...
# 1                   NaN            NaN       07.02.2012  ...
# 2                   NaN            NaN              NaN  ...
# 3                   NaN            NaN              NaN  ...
# 4                   NaN            NaN       02.02.2012  ...
# ...                 ...            ...              ...  ...
# 226308              NaN            NaN              NaN  ...
# 226309              NaN            NaN              NaN  ...
# 226310              NaN            NaN              NaN  ...
# 226311              NaN            NaN              NaN  ...
# 226312              NaN            NaN              NaN  ...
#
#                         PresentationName     Rank TaxonomicStatus  \
# 0                                  Biota   Sphere        Accepted
# 1                               Animalia  Kingdom        Accepted
# 2                                Archaea  Kingdom        Accepted
# 3                               Bacteria  Kingdom        Accepted
# 4                              Chromista  Kingdom        Accepted
# ...                                  ...      ...             ...
# 226308                     Moniliformida    Order        Accepted
# 226309              Oligacanthorhynchida    Order        Accepted
# 226310             Oligacanthorhynchidae   Family        Accepted
# 226311               Macracanthorhynchus    Genus        Accepted
# 226312  Macracanthorhynchus hirudinaceus  Species        Accepted
#
#         NomenclaturalStatuses             NameString          Author  \
# 0                         NaN                  Biota             NaN
# 1                         NaN               Animalia             NaN
# 2                         NaN                Archaea             NaN
# 3                         NaN               Bacteria             NaN
# 4                         NaN              Chromista      Caval.-Sm.
# ...                       ...                    ...             ...
# 226308                    NaN          Moniliformida             NaN
# 226309                    NaN   Oligacanthorhynchida             NaN
# 226310                    NaN  Oligacanthorhynchidae             NaN
# 226311                    NaN    Macracanthorhynchus             NaN
# 226312                    NaN           hirudinaceus  (Pallas, 1781)
#
#                      Reference   ValidFrom                            Comment  \
# 0                          NaN  01.01.2008                              Biota
# 1       CatalogueOfLife2008rev  30.04.2009  Importert fra "Catalogue of Life"
# 2       CatalogueOfLife2008rev  30.04.2009  Importert fra "Catalogue of Life"
# 3       CatalogueOfLife2008rev  30.04.2009  Importert fra "Catalogue of Life"
# 4                          NaN  30.04.2009                                NaN
# ...                        ...         ...                                ...
# 226308  CatalogueOfLife2008rev  30.04.2009  Importert fra "Catalogue of Life"
# 226309  CatalogueOfLife2008rev  30.04.2009  Importert fra "Catalogue of Life"
# 226310                     NaN  08.11.2012                                NaN
# 226311                     NaN  08.11.2012                                NaN
# 226312                     NaN  28.01.2015                                NaN
#
#        ExistsInNorway
# 0               False
# 1               False
# 2               False
# 3               False
# 4               False
# ...               ...
# 226308          False
# 226309          False
# 226310          False
# 226311          False
# 226312           True
#
# [226313 rows x 53 columns]>

# %%
artsnavnebase.loc[artsnavnebase["NameString"]=="Pinophyta"][["VernacularNameBokmaal"]]
# Out:
#      VernacularNameBokmaal
# 1340   nakenfrøete planter

# %% [markdown]
# ## Rødlista

# %%
url = "https://artsdatabanken.no/lister/rodlisteforarter/2021?Name=&SortBy=ScientificName&Meta=Visited&IsCheck=Area&IsCheck=Insekter&Export=true"
RL =pd.read_excel(url)
display(RL)
# , na_values = "NaN",dtype ="str"
# Out:
#        Id for vurderingen Vurderingsområde Ekspertkomité    Artsgruppe  \
# 0                   15090            Norge    Karplanter    Karplanter
# 1                   15002         Svalbard    Karplanter    Karplanter
# 2                    2444         Svalbard    Karplanter    Karplanter
# 3                   11455            Norge  Edderkoppdyr  Edderkoppdyr
# 4                   27083            Norge        Biller        Biller
# ...                   ...              ...           ...           ...
# 34165                5729            Norge        Vepser        Vepser
# 34166                4266            Norge        Biller        Biller
# 34167                6965            Norge        Sopper        Sopper
# 34168               32025            Norge        Sopper        Sopper
# 34169               29639            Norge      Tovinger      Tovinger
#
#                                          Taksonomisk sti  \
# 0      Plantae/Magnoliophyta/Monocots/Poales/Poaceae/...
# 1      Plantae/Magnoliophyta/Monocots/Poales/Poaceae/...
# 2      Plantae/Magnoliophyta/Monocots/Poales/Poaceae/...
# 3      Animalia/Arthropoda/Arachnida/Araneae/Linyphii...
# 4      Animalia/Arthropoda/Insecta/Coleoptera/Carabid...
# ...                                                  ...
# 34165  Animalia/Arthropoda/Insecta/Hymenoptera/Diapri...
# 34166  Animalia/Arthropoda/Insecta/Coleoptera/Staphyl...
# 34167  Fungi/Ascomycota/Sareomycetes/Sareales/Zythiac...
# 34168  Fungi/Ascomycota/Sordariomycetes/Hypocreales/N...
# 34169  Animalia/Arthropoda/Insecta/Diptera/Chironomid...
#
#        Vitenskapelig navn id          Vitenskapelig navn  \
# 0                     153890  ×Ammocalamagrostis baltica
# 1                     153891  ×Arctodupontia scleroclada
# 2                     153896    ×Pucciphippsia vacillans
# 3                       2644        Abacoproeces saltuum
# 4                       5565       Abax parallelepipedus
# ...                      ...                         ...
# 34165                 116045            Zygota subaptera
# 34166                  12000              Zyras collaris
# 34167                 133712              Zythia resinae
# 34168                 128479       Zythiostroma pinastri
# 34169                  17267        Aagaardia sivertseni
#
#                                Autor      Populærnavn Taksonomisk nivå  ...  \
# 0       (Flüggé ex Schrad.) P.Fourn.      østersjørør              Art  ...
# 1                    (Rupr.) Tzvelev   kongsfjordgras              Art  ...
# 2                   (Th.Fr.) Tzvelev     svalbardgras              Art  ...
# 3                    (L. Koch, 1872)  klippeedderkopp              Art  ...
# 4      (Piller & Mitterpacher, 1783)              NaN              Art  ...
# ...                              ...              ...              ...  ...
# 34165                (Thomson, 1859)              NaN              Art  ...
# 34166                (Paykull, 1800)              NaN              Art  ...
# 34167            (Ehrenb.) P. Karst.        kvaebeger              Art  ...
# 34168              (P. Karst.) Höhn.              NaN              Art  ...
# 34169                (Aagaard, 1979)              NaN              Art  ...
#
#         Trøndelag    Nordland       Troms    Finnmark   Jan Mayen   Nordsjøen  \
# 0      ikke kjent  ikke kjent  ikke kjent  ikke kjent  ikke kjent  ikke kjent
# 1      ikke kjent  ikke kjent  ikke kjent  ikke kjent  ikke kjent  ikke kjent
# 2      ikke kjent  ikke kjent  ikke kjent  ikke kjent  ikke kjent  ikke kjent
# 3             NaN         NaN         NaN         NaN         NaN         NaN
# 4             NaN         NaN         NaN         NaN         NaN         NaN
# ...           ...         ...         ...         ...         ...         ...
# 34165         NaN         NaN         NaN         NaN         NaN         NaN
# 34166         NaN         NaN         NaN         NaN         NaN         NaN
# 34167         NaN         NaN         NaN         NaN         NaN         NaN
# 34168         NaN         NaN         NaN         NaN         NaN         NaN
# 34169         NaN         NaN         NaN         NaN         NaN         NaN
#
#       Norskehavet Barentshavet nord og Polhavet Barentshavet sør  \
# 0      ikke kjent                    ikke kjent       ikke kjent
# 1      ikke kjent                    ikke kjent       ikke kjent
# 2      ikke kjent                    ikke kjent       ikke kjent
# 3             NaN                           NaN              NaN
# 4             NaN                           NaN              NaN
# ...           ...                           ...              ...
# 34165         NaN                           NaN              NaN
# 34166         NaN                           NaN              NaN
# 34167         NaN                           NaN              NaN
# 34168         NaN                           NaN              NaN
# 34169         NaN                           NaN              NaN
#
#       Grønlandshavet
# 0         ikke kjent
# 1         ikke kjent
# 2         ikke kjent
# 3                NaN
# 4                NaN
# ...              ...
# 34165            NaN
# 34166            NaN
# 34167            NaN
# 34168            NaN
# 34169            NaN
#
# [34170 rows x 50 columns]

# %% [markdown]
# ## Fremmedartslista

# %%
#FA_l = pd.read_csv("https://artsdatabanken.no/Fab2018/api/export/csv")
#FA_l = pd.read_csv("https://artsdatabanken.no/Fab2018/api/export/csv", chunksize=1, header=None, encoding='utf-8')
#url = "https://artsdatabanken.no/Fab2018/api/export/csv"
url = "https://artsdatabanken.no/lister/fremmedartslista/2023?Name=&SortBy=ScientificName&Meta=Visited&IsCheck=Area&IsCheck=dcin&IsCheck=AxBdescription&IsCheck=dcok&IsCheck=AssessedChangedCategory&IsCheck=ClimateAffected&IsCheck=ClimateNotAffected&IsCheck=eds&IsCheck=sal&IsCheck=Insecta&IsCheck=Crustacea&IsCheck=TaxonomicRank&TaxonRank=AssessedAtSameRank&IsCheck=Nta&IsCheck=Ntn&IsCheck=Importation&IsCheck=Introduction&IsCheck=Spread&Export=true"
FA_l = pd.read_excel(url)

# %%
# FA bruker en annen inndeling enn RL på Artsgruppe
# Basert på at både RL og FA bruker taksonomisk sti, så kan man bruke den som et oppslagsliste for å mappe verdier fra RL.artsgruppe til FA_l
# Subset RL with unique values of columns "Taksonomisk sti" and "Artsgruppe"
AG = RL[['Taksonomisk sti', 'Artsgruppe']].drop_duplicates()
AG_2 = FA_l[['Taksonomisk sti', 'Artsgruppe']].drop_duplicates()

# Function to find corresponding Artsgruppe in AG based on Taksonomisk sti
def find_artsgruppe(taksonomisk_sti):
    for index, row in AG.iterrows():
        if taksonomisk_sti in row['Taksonomisk sti']:
            return row['Artsgruppe']
    return None

# Add new column "Artsgruppe_2" to FA_l
FA_l['Artsgruppe'] = FA_l['Artsgruppe'].apply(lambda x: find_artsgruppe(x) if pd.notna(x) else None)

# %%
#FA_l[FA_l["Taksonomisk sti"].str.contains("Insecta")]
FA_l.loc[FA_l["Taksonomisk sti"].isna(),"Taksonomisk sti"]="-"
FA_l.loc[(FA_l["Artsgruppe"].isna()) & (FA_l["Taksonomisk sti"].str.contains("Insecta")),"Artsgruppe"]="Insekter"
FA_l.loc[(FA_l["Artsgruppe"].isna()) & (FA_l["Taksonomisk sti"].str.contains("Crustacea")),"Artsgruppe"]="Krepsdyr"
FA_l.loc[(FA_l["Artsgruppe"].isna()) & (FA_l["Taksonomisk sti"].str.contains("Molusca")),"Artsgruppe"]="Bløtdyr"
FA_l.loc[FA_l["Artsgruppe"].isna()]
#FA_l.loc[FA_l["Taksonomisk sti"].str.contains("Insecta"),"Artsgruppe"]#="Insekter"
# Out:
#       Id for vurderingen                Vurderingsområde  \
# 153                 4824  Fastlands-Norge med havområder
# 256                 1726  Fastlands-Norge med havområder
# 300                 1658  Fastlands-Norge med havområder
# 303                 1540  Fastlands-Norge med havområder
# 450                 4826  Fastlands-Norge med havområder
# 484                 5269  Fastlands-Norge med havområder
# 552                 4828  Fastlands-Norge med havområder
# 711                 2718  Fastlands-Norge med havområder
# 770                 1659  Fastlands-Norge med havområder
# 999                  490  Fastlands-Norge med havområder
# 1595                1587  Fastlands-Norge med havområder
# 1836                4836  Fastlands-Norge med havområder
# 2001                5693  Fastlands-Norge med havområder
# 2018                1677  Fastlands-Norge med havområder
# 2019                1641  Fastlands-Norge med havområder
# 2081                4838  Fastlands-Norge med havområder
# 2082                1552  Fastlands-Norge med havområder
# 2083                5022           Svalbard med kystsone
# 2085                4548  Fastlands-Norge med havområder
# 2386                4533  Fastlands-Norge med havområder
# 2388                5268  Fastlands-Norge med havområder
# 2389                4839  Fastlands-Norge med havområder
# 2563                4840  Fastlands-Norge med havområder
# 2650                4841  Fastlands-Norge med havområder
# 2869                4843  Fastlands-Norge med havområder
# 2870                1663  Fastlands-Norge med havområder
# 2871                1704  Fastlands-Norge med havområder
# 2872                1716  Fastlands-Norge med havområder
# 2873                4844  Fastlands-Norge med havområder
# 2874                1672  Fastlands-Norge med havområder
# 2875                1715  Fastlands-Norge med havområder
# 2911                4845  Fastlands-Norge med havområder
# 3035                1644  Fastlands-Norge med havområder
# 3141                2340  Fastlands-Norge med havområder
# 3142                1645  Fastlands-Norge med havområder
# 3285                4848  Fastlands-Norge med havområder
# 3287                4849  Fastlands-Norge med havområder
# 3295                4850  Fastlands-Norge med havområder
# 3582                4852  Fastlands-Norge med havområder
# 3739                4853  Fastlands-Norge med havområder
# 3740                4854  Fastlands-Norge med havområder
# 3741                4855  Fastlands-Norge med havområder
# 3810                4856  Fastlands-Norge med havområder
# 3813                1642  Fastlands-Norge med havområder
# 3817                1588  Fastlands-Norge med havområder
# 3818                1589  Fastlands-Norge med havområder
# 3899                4857  Fastlands-Norge med havområder
# 4027                4858  Fastlands-Norge med havområder
# 4028                4859  Fastlands-Norge med havområder
# 4217                2341  Fastlands-Norge med havområder
# 4440                4860  Fastlands-Norge med havområder
# 4441                4861  Fastlands-Norge med havområder
# 4489                1670  Fastlands-Norge med havområder
# 4797                4687  Fastlands-Norge med havområder
# 4815                4862  Fastlands-Norge med havområder
#
#                Ekspertkomité Artsgruppe  \
# 153   Rundormer og flatormer       None
# 256     Marine invertebrater       None
# 300   Rundormer og flatormer       None
# 303   Rundormer og flatormer       None
# 450   Rundormer og flatormer       None
# 484   Rundormer og flatormer       None
# 552   Rundormer og flatormer       None
# 711   Rundormer og flatormer       None
# 770   Rundormer og flatormer       None
# 999                    Alger       None
# 1595  Rundormer og flatormer       None
# 1836  Rundormer og flatormer       None
# 2001              Karplanter       None
# 2018  Rundormer og flatormer       None
# 2019  Rundormer og flatormer       None
# 2081  Rundormer og flatormer       None
# 2082  Rundormer og flatormer       None
# 2083    Marine invertebrater       None
# 2085  Limniske invertebrater       None
# 2386  Limniske invertebrater       None
# 2388  Rundormer og flatormer       None
# 2389  Rundormer og flatormer       None
# 2563  Rundormer og flatormer       None
# 2650  Rundormer og flatormer       None
# 2869  Rundormer og flatormer       None
# 2870  Rundormer og flatormer       None
# 2871  Rundormer og flatormer       None
# 2872  Rundormer og flatormer       None
# 2873  Rundormer og flatormer       None
# 2874  Rundormer og flatormer       None
# 2875  Rundormer og flatormer       None
# 2911  Rundormer og flatormer       None
# 3035  Rundormer og flatormer       None
# 3141  Rundormer og flatormer       None
# 3142  Rundormer og flatormer       None
# 3285  Rundormer og flatormer       None
# 3287  Rundormer og flatormer       None
# 3295  Rundormer og flatormer       None
# 3582  Rundormer og flatormer       None
# 3739  Rundormer og flatormer       None
# 3740  Rundormer og flatormer       None
# 3741  Rundormer og flatormer       None
# 3810  Rundormer og flatormer       None
# 3813  Rundormer og flatormer       None
# 3817  Rundormer og flatormer       None
# 3818  Rundormer og flatormer       None
# 3899  Rundormer og flatormer       None
# 4027  Rundormer og flatormer       None
# 4028  Rundormer og flatormer       None
# 4217  Rundormer og flatormer       None
# 4440  Rundormer og flatormer       None
# 4441  Rundormer og flatormer       None
# 4489  Rundormer og flatormer       None
# 4797  Limniske invertebrater       None
# 4815  Rundormer og flatormer       None
#
#                                         Taksonomisk sti  \
# 153   Animalia\Platyhelminthes\Trematoda\Strigeidida...
# 256   Animalia\Arthropoda\Pycnogonida\Incertae sedis...
# 300   Animalia\Nematoda\Secernentea\Strongylida\Angi...
# 303   Animalia\Nematoda\Secernentea\Spirurida\Anguil...
# 450   Animalia\Nematoda\Secernentea\Strongylida\Tric...
# 484   Animalia\Platyhelminthes\Cestoda\Caryophyllide...
# 552   Animalia\Nematoda\Secernentea\Ascaridida\Ascar...
# 711   Animalia\Nematoda\Secernentea\Aphelenchida\Aph...
# 770   Animalia\Nematoda\Secernentea\Strongylida\Tric...
# 999   Plantae\Charophyta\Charophyceae\Charales\Chara...
# 1595  Animalia\Platyhelminthes\Cestoda\Cyclophyllide...
# 1836  Animalia\Platyhelminthes\Trematoda\Echinostomi...
# 2001  Plantae\Ginkgophyta\Ginkgoopsida\Ginkgoales\Gi...
# 2018  Animalia\Nematoda\Secernentea\Tylenchida\Heter...
# 2019  Animalia\Nematoda\Secernentea\Tylenchida\Heter...
# 2081  Animalia\Platyhelminthes\Monogenea\Monopisthoc...
# 2082  Animalia\Platyhelminthes\Monogenea\Monopisthoc...
# 2083  Animalia\Platyhelminthes\Monogenea\Monopisthoc...
# 2085  Animalia\Rotifera\Eurotatoria\Bdelloidea\Habro...
# 2386  Animalia\Rotifera\Eurotatoria\Ploima\Brachioni...
# 2388  Animalia\Platyhelminthes\Cestoda\Caryophyllide...
# 2389  Animalia\Platyhelminthes\Cestoda\Caryophyllide...
# 2563  Animalia\Platyhelminthes\Monogenea\Monopisthoc...
# 2650  Animalia\Nematoda\Adenophorea\Dorylaimida\Dory...
# 2869  Animalia\Nematoda\Secernentea\Tylenchida\Meloi...
# 2870  Animalia\Nematoda\Secernentea\Tylenchida\Meloi...
# 2871  Animalia\Nematoda\Secernentea\Tylenchida\Meloi...
# 2872  Animalia\Nematoda\Secernentea\Tylenchida\Meloi...
# 2873  Animalia\Nematoda\Secernentea\Tylenchida\Meloi...
# 2874  Animalia\Nematoda\Secernentea\Tylenchida\Meloi...
# 2875  Animalia\Nematoda\Secernentea\Tylenchida\Meloi...
# 2911  Animalia\Platyhelminthes\Trematoda\Opisthorchi...
# 3035  Animalia\Nematoda\Secernentea\Strongylida\Moli...
# 3141  Animalia\Platyhelminthes\Monogenea\Monopisthoc...
# 3142                                                  -
# 3285  Animalia\Nematoda\Adenophorea\Dorylaimida\Dory...
# 3287  Animalia\Nematoda\Secernentea\Tylenchida\Tylen...
# 3295  Animalia\Nematoda\Enoplea\Triplonchida\Trichod...
# 3582  Animalia\Platyhelminthes\Turbellaria\Tricladid...
# 3739  Animalia\Nematoda\Secernentea\Tylenchida\Praty...
# 3740  Animalia\Nematoda\Secernentea\Tylenchida\Praty...
# 3741  Animalia\Nematoda\Secernentea\Tylenchida\Praty...
# 3810  Animalia\Platyhelminthes\Trematoda\Opisthorchi...
# 3813  Animalia\Platyhelminthes\Trematoda\Plagiorchii...
# 3817  Animalia\Platyhelminthes\Monogenea\Monopisthoc...
# 3818  Animalia\Platyhelminthes\Monogenea\Monopisthoc...
# 3899  Animalia\Nematoda\Secernentea\Tylenchida\Hoplo...
# 4027  Animalia\Nematoda\Secernentea\Tylenchida\Hoplo...
# 4028  Animalia\Nematoda\Secernentea\Tylenchida\Hoplo...
# 4217  Animalia\Platyhelminthes\Cestoda\Pseudophyllid...
# 4440  Animalia\Platyhelminthes\Cestoda\Pseudophyllid...
# 4441  Animalia\Platyhelminthes\Cestoda\Pseudophyllid...
# 4489  Animalia\Nematoda\Secernentea\Rhabditida\Stron...
# 4797  Animalia\Entoprocta\Incertae sedis\Pedicellini...
# 4815  Animalia\Platyhelminthes\Cestoda\Cyclophyllide...
#
#       Vitenskapelig navn id            Vitenskapelig navn  \
# 153                  146295                  Alaria alata
# 256                  128528          Ammothea hilgendorfi
# 300                  128890       Angiostrongylus vasorum
# 303                  128551      Anguillicoloides crassus
# 450                  216418            Ashworthius sidemi
# 484                  220446  Atractolytocestus huronensis
# 552                  216422       Baylisascaris procyonis
# 711                  128494    Bursaphelenchus xylophilus
# 770                  128888   Camelostrongylus mentulatus
# 999                  121449               Chara connivens
# 1595                 128898   Echinococcus multilocularis
# 1836                 216439            Fascioloides magna
# 2001                 217656                 Ginkgo biloba
# 2018                 128876             Globodera pallida
# 2019                 128875       Globodera rostochiensis
# 2081                 216444        Gyrodactylus nebulosus
# 2082                 127730          Gyrodactylus salaris
# 2083                 127730          Gyrodactylus salaris
# 2085                 216149        Habrotrocha constricta
# 2386                 138215      Kellicottia bostoniensis
# 2388                 220444             Khawia japonensis
# 2389                 216446               Khawia sinensis
# 2563                 216448         Ligictaluridus pricei
# 2650                 216453          Longidorus macrosoma
# 2869                 216456         Meloidogyne artiellia
# 2870                 128878         Meloidogyne chitwoodi
# 2871                 128879            Meloidogyne fallax
# 2872                 128880             Meloidogyne hapla
# 2873                 216457              Meloidogyne mali
# 2874                 128882             Meloidogyne minor
# 2875                 128881             Meloidogyne naasi
# 2911                 216459               Metorchis bilis
# 3035                 128885            Nematodirus battus
# 3141                 170477           Onchocleidus dispar
# 3142                 128925              Onchocleidus sp.
# 3285                 216463        Paralongidorus maximus
# 3287                 216465           Paranguina agropyri
# 3295                 216469         Paratrichodorus minor
# 3582                 216477          Platydemus manokwari
# 3739                 216480       Pratylenchus brachyurus
# 3740                 216481          Pratylenchus thornei
# 3741                 216482           Pratylenchus vulnus
# 3810                 216484    Pseudamphistomum truncatum
# 3813                 128554     Pseudobacciger harengulae
# 3817                 128557  Pseudodactylogyrus anguillae
# 3818                 128558       Pseudodactylogyrus bini
# 3899                 216488            Radopholus similis
# 4027                 216490        Rotylenchus buxophilus
# 4028                 216491          Rotylenchus robustus
# 4217                 170480    Schyzocotyle acheilognathi
# 4440                 216493   Spirometra erinaceieuropaei
# 4441                 216494            Spirometra mansoni
# 4489                 128892     Strongyloides stercoralis
# 4797                 217088            Urnatella gracilis
# 4815                 216496    Valipora campylancristrota
#
#                                                 Autor            Populærnavn  \
# 153                                     (Goeze, 1782)                    NaN
# 256                                               NaN                    NaN
# 300                                  (Railliet, 1866)                    NaN
# 303   (Kuwahara, Niimi & Itagaki, 1974) Moravec, 2006                    NaN
# 450                                      Schulz, 1933                    NaN
# 484                                     Anthony, 1958                    NaN
# 552                     (Stefanski & Zarnowski, 1951)                    NaN
# 711                          (Steiner & Buhrer, 1934)        furuvednematode
# 770                          (Railliet & Henry, 1909)                    NaN
# 999                                               NaN                    NaN
# 1595                                   Leuckart, 1863  revens dvergbendelorm
# 1836                                    (Bassi, 1875)                    NaN
# 2001                                               L.                 ginkgo
# 2018                                      Stone, 1973                    NaN
# 2019           (Wollenweber, 1923) Skarbilovich, 1959                    NaN
# 2081                        Kritsky and Mizelle, 1968                    NaN
# 2082                                   Malmberg, 1957                    NaN
# 2083                                   Malmberg, 1957                    NaN
# 2085                                 (Dujardin, 1841)                    NaN
# 2386                                (Rousselet, 1908)                    NaN
# 2388                                 (Yamaguti, 1934)                    NaN
# 2389                                        Hsu, 1935                    NaN
# 2563                                  (Mueller, 1936)                    NaN
# 2650                                     Hooper, 1961                    NaN
# 2869                                   Franklin, 1961                    NaN
# 2870           Golden, O'Bannon, Santo & Finley, 1980                    NaN
# 2871                                    Karssen, 1996                    NaN
# 2872                                   Chitwood, 1949                    NaN
# 2873                   Itoh, Ohshima & Ichinohe, 1969                    NaN
# 2874                             Karssen et al., 2004                    NaN
# 2875                                   Franklin, 1965                    NaN
# 2911                                    (Braun, 1790)                    NaN
# 3035                           Crofton & Thomas, 1951                    NaN
# 3141                                  (Mueller, 1936)                    NaN
# 3142                                              NaN                    NaN
# 3285                                 (Butschli, 1874)                    NaN
# 3287                                  Kirjanova, 1955                    NaN
# 3295                                  (Colbran, 1956)                    NaN
# 3582                              De Beauchamp, 1963[                    NaN
# 3739                                  (Godfrey, 1929)                    NaN
# 3740                               Sher & Allen, 1953                    NaN
# 3741                             Allen & Jensen, 1951                    NaN
# 3810                                 (Rudolphi, 1819)                    NaN
# 3813                                 (Yamaguti, 1938)                    NaN
# 3817                           (Yin & Sproston, 1948)                    NaN
# 3818                                  (Kikuchi, 1929)                    NaN
# 3899                                     (Cobb, 1893)                    NaN
# 4027                                   (Golden, 1956)                    NaN
# 4028                                   (de Man, 1876)                    NaN
# 4217                                 (Yamaguti, 1934)                    NaN
# 4440                                 (Rudolphi, 1810)                    NaN
# 4441                               Faust et al., 1929                    NaN
# 4489                                    (Bavay, 1876)                    NaN
# 4797                                      Leidy, 1851                    NaN
# 4815                                     (Wedl, 1855)                    NaN
#
#                Fremmedartsstatus  ... Geografisk variasjon i risiko  \
# 153                 Ikke fremmed  ...                           NaN
# 256                  Dørstokkart  ...                           Nei
# 300   Selvstendig reproduserende  ...                           Nei
# 303   Selvstendig reproduserende  ...                           Nei
# 450                  Dørstokkart  ...                           Nei
# 484              Horisontskannet  ...                           NaN
# 552                  Dørstokkart  ...                           Nei
# 711                  Dørstokkart  ...                            Ja
# 770   Selvstendig reproduserende  ...                           Nei
# 999              Horisontskannet  ...                           NaN
# 1595                 Dørstokkart  ...                            Ja
# 1836                 Dørstokkart  ...                            Ja
# 2001             Horisontskannet  ...                           NaN
# 2018  Selvstendig reproduserende  ...                           Nei
# 2019  Selvstendig reproduserende  ...                           Nei
# 2081             Horisontskannet  ...                           NaN
# 2082  Selvstendig reproduserende  ...                            Ja
# 2083                 Dørstokkart  ...                           Nei
# 2085                 Dørstokkart  ...                           Nei
# 2386                 Dørstokkart  ...                           Nei
# 2388             Horisontskannet  ...                           NaN
# 2389             Horisontskannet  ...                           NaN
# 2563             Horisontskannet  ...                           NaN
# 2650                 Dørstokkart  ...                           Nei
# 2869                 Dørstokkart  ...                           Nei
# 2870                 Dørstokkart  ...                           Nei
# 2871                 Dørstokkart  ...                           Nei
# 2872  Selvstendig reproduserende  ...                           Nei
# 2873                 Dørstokkart  ...                           Nei
# 2874                 Dørstokkart  ...                           Nei
# 2875  Selvstendig reproduserende  ...                           Nei
# 2911                 Dørstokkart  ...                            Ja
# 3035  Selvstendig reproduserende  ...                           Nei
# 3141  Selvstendig reproduserende  ...                           Nei
# 3142  Selvstendig reproduserende  ...                           Nei
# 3285                 Dørstokkart  ...                           Nei
# 3287                 Dørstokkart  ...                           Nei
# 3295                 Dørstokkart  ...                           Nei
# 3582             Horisontskannet  ...                           NaN
# 3739             Horisontskannet  ...                           NaN
# 3740                 Dørstokkart  ...                           Nei
# 3741                 Dørstokkart  ...                           Nei
# 3810                 Dørstokkart  ...                            Ja
# 3813                 Dørstokkart  ...                           Nei
# 3817  Selvstendig reproduserende  ...                            Ja
# 3818                 Dørstokkart  ...                           Nei
# 3899                 Dørstokkart  ...                           Nei
# 4027  Selvstendig reproduserende  ...                           Nei
# 4028  Selvstendig reproduserende  ...                           Nei
# 4217                 Dørstokkart  ...                            Ja
# 4440                 Dørstokkart  ...                            Ja
# 4441             Horisontskannet  ...                           NaN
# 4489                 Dørstokkart  ...                            Ja
# 4797                 Dørstokkart  ...                           Nei
# 4815        Etablert per år 1800  ...                           NaN
#
#                 Årsak til geografisk variasjon i risiko  \
# 153                                                 NaN
# 256                                                 NaN
# 300                                                 NaN
# 303                                                 NaN
# 450                                                 NaN
# 484                                                 NaN
# 552                                                 NaN
# 711   Artens evne til reproduksjon og/eller sprednin...
# 770                                                 NaN
# 999                                                 NaN
# 1595  Artens økologiske effekt består utelukkende i ...
# 1836  Artens evne til reproduksjon og/eller sprednin...
# 2001                                                NaN
# 2018                                                NaN
# 2019                                                NaN
# 2081                                                NaN
# 2082  Artens økologiske effekter er begrenset til be...
# 2083                                                NaN
# 2085                                                NaN
# 2386                                                NaN
# 2388                                                NaN
# 2389                                                NaN
# 2563                                                NaN
# 2650                                                NaN
# 2869                                                NaN
# 2870                                                NaN
# 2871                                                NaN
# 2872                                                NaN
# 2873                                                NaN
# 2874                                                NaN
# 2875                                                NaN
# 2911  Artens økologiske effekt består utelukkende i ...
# 3035                                                NaN
# 3141                                                NaN
# 3142                                                NaN
# 3285                                                NaN
# 3287                                                NaN
# 3295                                                NaN
# 3582                                                NaN
# 3739                                                NaN
# 3740                                                NaN
# 3741                                                NaN
# 3810  Artens evne til reproduksjon og/eller sprednin...
# 3813                                                NaN
# 3817  Artens evne til reproduksjon og/eller sprednin...
# 3818                                                NaN
# 3899                                                NaN
# 4027                                                NaN
# 4028                                                NaN
# 4217  Artens evne til reproduksjon og/eller sprednin...
# 4440  Artens økologiske effekter er begrenset til be...
# 4441                                                NaN
# 4489  Artens evne til reproduksjon og/eller sprednin...
# 4797                                                NaN
# 4815                                                NaN
#
#      Klimaeffekter invasjonspotensial Klimaeffekter økologisk effekt  \
# 153                               NaN                            NaN
# 256                               Nei                            Nei
# 300                               Nei                            Nei
# 303                                Ja                             Ja
# 450                               Nei                            Nei
# 484                               NaN                            NaN
# 552                               Nei                            Nei
# 711                                Ja                             Ja
# 770                                Ja                            Nei
# 999                               NaN                            NaN
# 1595                               Ja                            Nei
# 1836                               Ja                            Nei
# 2001                              NaN                            NaN
# 2018                               Ja                             Ja
# 2019                               Ja                             Ja
# 2081                              NaN                            NaN
# 2082                               Ja                            Nei
# 2083                              Nei                            Nei
# 2085                              Nei                            Nei
# 2386                              Nei                            Nei
# 2388                              NaN                            NaN
# 2389                              NaN                            NaN
# 2563                              NaN                            NaN
# 2650                               Ja                             Ja
# 2869                               Ja                            Nei
# 2870                               Ja                            Nei
# 2871                               Ja                            Nei
# 2872                               Ja                             Ja
# 2873                              Nei                            Nei
# 2874                               Ja                             Ja
# 2875                               Ja                            Nei
# 2911                              Nei                            Nei
# 3035                               Ja                             Ja
# 3141                               Ja                            Nei
# 3142                               Ja                            Nei
# 3285                               Ja                             Ja
# 3287                               Ja                            Nei
# 3295                               Ja                             Ja
# 3582                              NaN                            NaN
# 3739                              NaN                            NaN
# 3740                               Ja                             Ja
# 3741                              Nei                            Nei
# 3810                               Ja                            Nei
# 3813                               Ja                            Nei
# 3817                               Ja                            Nei
# 3818                              Nei                            Nei
# 3899                               Ja                            Nei
# 4027                               Ja                            Nei
# 4028                              Nei                            Nei
# 4217                              Nei                            Nei
# 4440                              Nei                            Nei
# 4441                              NaN                            NaN
# 4489                              Nei                             Ja
# 4797                               Ja                            Nei
# 4815                              NaN                            NaN
#
#       Kjent forekomstareal  Antatt forekomstareal beste anslag  \
# 153                    NaN                                 NaN
# 256                    NaN                                 NaN
# 300                   56.0                             10132.0
# 303                   48.0                              1600.0
# 450                    NaN                                 NaN
# 484                    NaN                                 NaN
# 552                    NaN                                 NaN
# 711                    NaN                                 NaN
# 770                   24.0                               100.0
# 999                    NaN                                 NaN
# 1595                   NaN                                 NaN
# 1836                   NaN                                 NaN
# 2001                   NaN                                 NaN
# 2018                 244.0                               488.0
# 2019               10000.0                             16000.0
# 2081                   NaN                                 NaN
# 2082                  96.0                               496.0
# 2083                   NaN                                 NaN
# 2085                   NaN                                 NaN
# 2386                   NaN                                 NaN
# 2388                   NaN                                 NaN
# 2389                   NaN                                 NaN
# 2563                   NaN                                 NaN
# 2650                   NaN                                 NaN
# 2869                   NaN                                 NaN
# 2870                   NaN                                 NaN
# 2871                   NaN                                 NaN
# 2872                  40.0                               160.0
# 2873                   NaN                                 NaN
# 2874                   NaN                                 NaN
# 2875                  28.0                               168.0
# 2911                   NaN                                 NaN
# 3035                1940.0                              5820.0
# 3141                   4.0                                 8.0
# 3142                   4.0                                 8.0
# 3285                   NaN                                 NaN
# 3287                   NaN                                 NaN
# 3295                   NaN                                 NaN
# 3582                   NaN                                 NaN
# 3739                   NaN                                 NaN
# 3740                   NaN                                 NaN
# 3741                   NaN                                 NaN
# 3810                   NaN                                 NaN
# 3813                   NaN                                 NaN
# 3817                  60.0                               120.0
# 3818                   NaN                                 NaN
# 3899                   NaN                                 NaN
# 4027                   8.0                                40.0
# 4028                   4.0                                24.0
# 4217                   NaN                                 NaN
# 4440                   NaN                                 NaN
# 4441                   NaN                                 NaN
# 4489                   NaN                                 NaN
# 4797                   NaN                                 NaN
# 4815                   NaN                                 NaN
#
#       Fremtidig forekomstareal beste anslag  \
# 153                                       0
# 256                                      20
# 300                                   30000
# 303                                    4000
# 450                                     280
# 484                                       0
# 552                                       0
# 711                                    1616
# 770                                     400
# 999                                       0
# 1595                                    180
# 1836                                     84
# 2001                                      0
# 2018                                   1952
# 2019                                  24000
# 2081                                      0
# 2082                                    636
# 2083                                     12
# 2085                                      8
# 2386                                     12
# 2388                                      0
# 2389                                      0
# 2563                                      0
# 2650                                     44
# 2869                                     20
# 2870                                    172
# 2871                                    172
# 2872                                    800
# 2873                                    356
# 2874                                     44
# 2875                                    300
# 2911                                      8
# 3035                                   6000
# 3141                                     16
# 3142                                     16
# 3285                                     32
# 3287                                    304
# 3295                                    168
# 3582                                      0
# 3739                                      0
# 3740                                    220
# 3741                                     44
# 3810                                     56
# 3813                                    800
# 3817                                    240
# 3818                                    100
# 3899                                     12
# 4027                                    120
# 4028                                    400
# 4217                                     12
# 4440                                     32
# 4441                                      0
# 4489                                      4
# 4797                                     24
# 4815                                      0
#
#       Ant. forekomster fra én introduksjon beste anslag  \
# 153                                                 NaN
# 256                                                 4.0
# 300                                                 NaN
# 303                                                 NaN
# 450                                                40.0
# 484                                                 NaN
# 552                                                 0.0
# 711                                                15.0
# 770                                                 NaN
# 999                                                 NaN
# 1595                                               30.0
# 1836                                               20.0
# 2001                                                NaN
# 2018                                                NaN
# 2019                                                NaN
# 2081                                                NaN
# 2082                                                NaN
# 2083                                                2.0
# 2085                                                2.0
# 2386                                                2.0
# 2388                                                NaN
# 2389                                                NaN
# 2563                                                NaN
# 2650                                                8.0
# 2869                                                3.0
# 2870                                               42.0
# 2871                                               42.0
# 2872                                                NaN
# 2873                                               10.0
# 2874                                               10.0
# 2875                                                NaN
# 2911                                                1.0
# 3035                                                NaN
# 3141                                                NaN
# 3142                                                NaN
# 3285                                                4.0
# 3287                                                8.0
# 3295                                                8.0
# 3582                                                NaN
# 3739                                                NaN
# 3740                                               12.0
# 3741                                                8.0
# 3810                                               10.0
# 3813                                              200.0
# 3817                                                NaN
# 3818                                               25.0
# 3899                                                1.0
# 4027                                                NaN
# 4028                                                NaN
# 4217                                                1.0
# 4440                                                5.0
# 4441                                                NaN
# 4489                                                0.0
# 4797                                                5.0
# 4815                                                NaN
#
#       Ant. ytterligere introduksjoner beste anslag  \
# 153                                            NaN
# 256                                            1.0
# 300                                            NaN
# 303                                            NaN
# 450                                            2.0
# 484                                            NaN
# 552                                            0.0
# 711                                           12.0
# 770                                            NaN
# 999                                            NaN
# 1595                                           2.0
# 1836                                           1.0
# 2001                                           NaN
# 2018                                           NaN
# 2019                                           NaN
# 2081                                           NaN
# 2082                                           NaN
# 2083                                           1.0
# 2085                                           0.0
# 2386                                           1.0
# 2388                                           NaN
# 2389                                           NaN
# 2563                                           NaN
# 2650                                           2.0
# 2869                                           2.0
# 2870                                           1.0
# 2871                                           1.0
# 2872                                           NaN
# 2873                                          10.0
# 2874                                           1.0
# 2875                                           NaN
# 2911                                           1.0
# 3035                                           NaN
# 3141                                           NaN
# 3142                                           NaN
# 3285                                           3.0
# 3287                                          12.0
# 3295                                           8.0
# 3582                                           NaN
# 3739                                           NaN
# 3740                                           6.0
# 3741                                           2.0
# 3810                                           2.0
# 3813                                           0.0
# 3817                                           NaN
# 3818                                           0.0
# 3899                                           2.0
# 4027                                           NaN
# 4028                                           NaN
# 4217                                           2.0
# 4440                                           2.0
# 4441                                           NaN
# 4489                                           1.0
# 4797                                           1.0
# 4815                                           NaN
#
#                                              Naturtyper
# 153                                                 NaN
# 256   beskyttet infralitoral fastbunn; finmaterialdo...
# 300   myr- og sumpskogsmark; strandsumpskogsmark; se...
# 303                                                 NaN
# 450                                                 NaN
# 484                                                 NaN
# 552                                                 NaN
# 711                                  fastmarksskogsmark
# 770   sterkt endret fastmark med preg av semi-naturl...
# 999                                                 NaN
# 1595  oppdyrket varig eng; semi-naturlig eng; sterkt...
# 1836                                                NaN
# 2001                                                NaN
# 2018                                               åker
# 2019                                               åker
# 2081                                                NaN
# 2082  elvevannmasser; lagdelte fullsirkulerende (mon...
# 2083                                                NaN
# 2085                                                NaN
# 2386  moderat kalkrike lagdelte vannmasser med enkel...
# 2388                                                NaN
# 2389                                                NaN
# 2563                                                NaN
# 2650                                 fastmarksskogsmark
# 2869  sterkt endret, hyppig bearbeidet fastmark med ...
# 2870                                               åker
# 2871                                               åker
# 2872  fastmarksskogsmark; åker; plantasjeskog; eng-a...
# 2873                                 fastmarksskogsmark
# 2874                   plener, parker og liknende; åker
# 2875                   åker; plener, parker og liknende
# 2911                                                NaN
# 3035                                                NaN
# 3141  ikke-lagdelte (polymiktiske) vannmasser med fi...
# 3142  ikke-lagdelte (polymiktiske) vannmasser med fi...
# 3285  treplantasje; åker; sterkt endret, varig fastm...
# 3287                   plener, parker og liknende; åker
# 3295  atlantisk høymyr; terrengdekkende myr; semi-na...
# 3582                                                NaN
# 3739                                                NaN
# 3740                                               åker
# 3741                                               åker
# 3810                                                NaN
# 3813  sirkulerende vannmasser i fysisk avgrensete sa...
# 3817                                                NaN
# 3818                                                NaN
# 3899                                                NaN
# 4027                                                NaN
# 4028                                                NaN
# 4217                                                NaN
# 4440                                                NaN
# 4441                                                NaN
# 4489                                                NaN
# 4797  svært kalkrik fin innsjø-sedimentbunn i plante...
# 4815                                                NaN
#
# [55 rows x 37 columns]

# %%
FA_l["Kriterium_Fremmede_arter"]="X"
FA_l.loc[FA_l["Vurderingsområde"]=="Fastlands-Norge med havområder","Vurderingsområde"]="Norge"# Harmonisere med rødlisten

# %% [markdown]
# ### ADB statuser

# %%
#FA_l.columns#.isin([RL.columns])

# %%
FA = FA_l[['Vitenskapelig navn id','Vitenskapelig navn','Populærnavn','Risikokategori 2023','Vurderingsområde', 'Ekspertkomité', 'Artsgruppe','Kriterium_Fremmede_arter']]
RL = RL[['Vitenskapelig navn id','Vitenskapelig navn','Populærnavn','Kategori 2021','Andel av europeisk populasjon i Norge','Vurderingsområde', 'Ekspertkomité', 'Artsgruppe']]
# Merger på alle kolonner som de har til felles
ADB = FA.merge(RL, on = list(FA_l.columns.intersection(RL.columns)), how = "outer")
#ADB = pd.concat([FA_l[['Vitenskapelig navn id','Vitenskapelig navn','Taksonomisk sti','Populærnavn','Risikokategori 2023','Vurderingsområde', 'Ekspertkomité', 'Artsgruppe','Kriterium_Fremmede_arter']],RL[['Taksonomisk sti','Vitenskapelig navn id','Vitenskapelig navn','Populærnavn','Kategori 2021','Andel av europeisk populasjon i Norge','Vurderingsområde', 'Ekspertkomité', 'Artsgruppe']]])

# %% [markdown]
# # Forvaltningsstatus

# %%
import pandas as pd
url = "https://geoapi.t.aks.miljodirektoratet.no/forvaltningsstatus_arter/v1/getStatusAsCsv"
forvaltningsstatus =pd.read_csv(url, sep = ",")
display(forvaltningsstatus)
# Out:
#      objectid  vitenskapelig_navn_id  \
# 0           1                   1590
# 1           2                   3461
# 2           3                   3471
# 3           4                   3487
# 4           5                   3501
# ..        ...                    ...
# 437       438                 121126
# 438       439                 121308
# 439       440                 170109
# 440       441                 192388
# 441       442                 214235
#
#                               vitenskapelig_navn       norsk_navn  freda  \
# 0                               Zootoca vivipara     nordfirfisle      0
# 1                             Anas platyrhynchos         stokkand      0
# 2                                    Anser anser           grågås      0
# 3                                Aythya fuligula          toppand      0
# 4                             Bucephala clangula          kvinand      0
# ..                                           ...              ...    ...
# 437                 Vertigo (Vertilla) angustior   smalknøttsnegl      0
# 438  Margaritifera (Margaritifera) margaritifera      elvemusling      0
# 439                              Mannia triandra              NaN      0
# 440                  Brachythecium novae-angliae          oremose      0
# 441                      Campylophyllum montanum  huldrebekkemose      0
#
#      prioritert  spesielle_oekologiske_former bonn_kategori  \
# 0             0                             0           NaN
# 1             0                             0      Annex II
# 2             0                             0      Annex II
# 3             0                             0      Annex II
# 4             0                             0      Annex II
# ..          ...                           ...           ...
# 437           0                             0           NaN
# 438           0                             0           NaN
# 439           0                             0           NaN
# 440           0                             0           NaN
# 441           0                             0           NaN
#
#     bonn_bevaringsstatus bern_kategori  bern_bevaringsstatus ospar_kategori  \
# 0                    NaN     Annex III                   NaN            NaN
# 1                    NaN     Annex III                   NaN            NaN
# 2                    NaN     Annex III                   NaN            NaN
# 3                    NaN     Annex III                   NaN            NaN
# 4                    NaN     Annex III                   NaN            NaN
# ..                   ...           ...                   ...            ...
# 437                  NaN  Annex I (R6)                   NaN            NaN
# 438                  NaN  Annex I (R6)                   NaN            NaN
# 439                  NaN  Annex I (R6)                   NaN            NaN
# 440                  NaN  Annex I (R6)                   NaN            NaN
# 441                  NaN  Annex I (R6)                   NaN            NaN
#
#     ospar_bevaringsstatus                                     eea_id  \
# 0                     NaN  https://eunis.eea.europa.eu/species/24156
# 1                     NaN    https://eunis.eea.europa.eu/species/869
# 2                     NaN    https://eunis.eea.europa.eu/species/876
# 3                     NaN    https://eunis.eea.europa.eu/species/909
# 4                     NaN    https://eunis.eea.europa.eu/species/923
# ..                    ...                                        ...
# 437                   NaN    https://eunis.eea.europa.eu/species/367
# 438                   NaN    https://eunis.eea.europa.eu/species/245
# 439                   NaN   https://eunis.eea.europa.eu/species/4273
# 440                   NaN  https://eunis.eea.europa.eu/species/19877
# 441                   NaN   https://eunis.eea.europa.eu/species/3724
#
#                        roedliste_statuser
# 0    LC/LC - Livskraftig/LC - Livskraftig
# 1    LC/LC - Livskraftig/LC - Livskraftig
# 2    LC/LC - Livskraftig/LC - Livskraftig
# 3    LC/LC - Livskraftig/LC - Livskraftig
# 4    LC/LC - Livskraftig/LC - Livskraftig
# ..                                    ...
# 437                                NT/-/-
# 438                                VU/-/-
# 439                                CR/-/-
# 440                 NT/LC - Livskraftig/-
# 441                      EN/VU - Sårbar/-
#
# [442 rows x 15 columns]

# %%
forvaltningsstatus["Streng"]=((~forvaltningsstatus["bern_kategori"].fillna("-").str.contains("III")) & (forvaltningsstatus["bern_kategori"].fillna("-").str.contains("I"))) | (forvaltningsstatus[["ospar_kategori", "bonn_kategori"]].apply(lambda x: x.notna().any(), axis = 1))
forvaltningsstatus["Dårlig"] = ((forvaltningsstatus["bern_bevaringsstatus"].notna() & forvaltningsstatus["bonn_bevaringsstatus"].notna() & forvaltningsstatus["ospar_bevaringsstatus"].notna()) | (RL["Andel av europeisk populasjon i Norge"].str.contains("50")) | forvaltningsstatus["roedliste_statuser"].str.contains("EN|CR|VU|DD|NT"))
forvaltningsstatus.loc[forvaltningsstatus["Streng"] & forvaltningsstatus["Dårlig"],"Hensynskrevende"] = "Spesielt"
forvaltningsstatus.loc[forvaltningsstatus["Streng"] & ~forvaltningsstatus["Dårlig"],"Hensynskrevende"] = "Annet"

# %% [markdown]
# # Verdsatte arter

# %%
import numpy as np
import pandas as pd

# %%
ADB = ADB.rename(columns={'Kategori 2021':"RL_status","Vitenskapelig navn id":"vitenskapelig_navn_id","Vitenskapelig navn":"vitenskapelig_navn"})

# %%
VitID2 = pd.DataFrame(data = {"vitenskapelig_navn_id":np.concatenate([forvaltningsstatus["vitenskapelig_navn_id"],ADB["vitenskapelig_navn_id"]])})
VitID = pd.DataFrame(data = {"vitenskapelig_navn_id":VitID2["vitenskapelig_navn_id"].unique()})

# %%
AV = VitID.merge(right = ADB, how = "left", on ="vitenskapelig_navn_id")
AV = AV.merge(right = forvaltningsstatus.drop(columns=['vitenskapelig_navn']), how = "left", on = ["vitenskapelig_navn_id"])

# %%
# Hardkoder at artene i spesielle økologiske former er fugler
AV.loc[AV["spesielle_oekologiske_former"]==1,"Artsgruppe"]="Fugler"
# Tilsvarende for prioriterte arter
AV.loc[AV["vitenskapelig_navn"]=="Limosa limosa islandica","Artsgruppe"]="Fugler"
AV[(AV["prioritert"]==1)]
# Og fikser deres norske navn
AV.loc[(AV["Populærnavn"].isna()) & (~AV["norsk_navn"].isna()), "Populærnavn"] = AV["norsk_navn"]

# %%
# Out:
#      vitenskapelig_navn_id vitenskapelig_navn        Populærnavn  \
# 162                   3685                NaN  nordlig sildemåke
#
#     Risikokategori 2023 Vurderingsområde Ekspertkomité Artsgruppe  \
# 162                 NaN              NaN           NaN     Fugler
#
#     Kriterium_Fremmede_arter RL_status Andel av europeisk populasjon i Norge  \
# 162                      NaN       NaN                                   NaN
#
#      ...  bonn_bevaringsstatus bern_kategori  bern_bevaringsstatus  \
# 162  ...                   NaN           NaN                   NaN
#
#      ospar_kategori  ospar_bevaringsstatus eea_id roedliste_statuser Streng  \
# 162             NaN                    NaN    NaN                NaN  False
#
#      Dårlig Hensynskrevende
# 162   False             NaN
#
# [1 rows x 26 columns]

# %%
# "Øvrige dyr"
AV.loc[AV["Artsgruppe"].isna(), "Artsgruppe"]  = "Øvrige dyr"

# %%
# Function to map values
def map_values(row):
    #print(row)
    #if row['freda'] == 1 or row['prioritert'] == 1:
        #return 'Svært stor verdi'
    if (row['RL_status'] == 'LC') or (row["Hensynskrevende"]=="Annet"):
        return 'Noe verdi'
    elif row['RL_status'] in ['NT', 'DD']:
        return 'Middels verdi'
    elif (row['RL_status'] == 'VU') or (row["Hensynskrevende"]=="Spesielt"):
        return 'Stor verdi'
    elif (row['RL_status'] in ['CR', 'EN']) or (row['freda'] == 1 or row['prioritert'] == 1):
        return 'Svært stor verdi'
    else:
        return "-"

# Apply the function to the DataFrame
AV['Forvaltningsverdi'] = AV.apply(map_values, axis=1)

# %%
# Function to set criteria based on RL_status
def set_criteria(row):
    if row['RL_status'] == 'NT':
        row['Kriterium_NT'] = 'X'
    elif row['RL_status'] == 'DD':
        row['Kriterium_DD'] = 'X'
    elif row['RL_status'] == 'VU':
        row['Kriterium_sårbar art'] = 'X'
    elif row['RL_status'] == 'CR':
        row['Kriterium_kritisk trua art'] = 'X'
    elif row['RL_status'] == 'EN':
        row['Kriterium_sterkt trua art'] = 'X'
    elif row["Hensynskrevende"]=="Spesielt":
        row['Kriterium_Andre spesielt_hensynskrevende_arter']='X'
    elif row["Hensynskrevende"]=="Annet":
        row['Kriterium_Hensynskrevende_arter']='X'        
    return row

# Apply the function to each row
AV = AV.apply(set_criteria, axis=1)
AV.head()
# Out:
#   Andel av europeisk populasjon i Norge            Artsgruppe Dårlig  \
# 0                                   NaN  Amfibier og reptiler  False
# 1                               1 - 5 %                Fugler   True
# 2                              5 - 25 %                Fugler   True
# 3                               1 - 5 %                Fugler  False
# 4                               1 - 5 %                Fugler  False
#
#           Ekspertkomité Forvaltningsverdi Hensynskrevende  \
# 0  Amfibier og reptiler         Noe verdi             NaN
# 1                Fugler         Noe verdi        Spesielt
# 2                Fugler         Noe verdi        Spesielt
# 3                Fugler         Noe verdi           Annet
# 4                Fugler         Noe verdi           Annet
#
#   Kriterium_Andre spesielt_hensynskrevende_arter Kriterium_DD  \
# 0                                            NaN          NaN
# 1                                              X          NaN
# 2                                              X          NaN
# 3                                            NaN          NaN
# 4                                            NaN          NaN
#
#   Kriterium_Fremmede_arter Kriterium_Hensynskrevende_arter  ... freda  \
# 0                      NaN                             NaN  ...   0.0
# 1                      NaN                             NaN  ...   0.0
# 2                      NaN                             NaN  ...   0.0
# 3                      NaN                               X  ...   0.0
# 4                      NaN                               X  ...   0.0
#
#      norsk_navn objectid ospar_bevaringsstatus ospar_kategori prioritert  \
# 0  nordfirfisle      1.0                   NaN            NaN        0.0
# 1      stokkand      2.0                   NaN            NaN        0.0
# 2        grågås      3.0                   NaN            NaN        0.0
# 3       toppand      4.0                   NaN            NaN        0.0
# 4       kvinand      5.0                   NaN            NaN        0.0
#
#                      roedliste_statuser spesielle_oekologiske_former  \
# 0  LC/LC - Livskraftig/LC - Livskraftig                          0.0
# 1  LC/LC - Livskraftig/LC - Livskraftig                          0.0
# 2  LC/LC - Livskraftig/LC - Livskraftig                          0.0
# 3  LC/LC - Livskraftig/LC - Livskraftig                          0.0
# 4  LC/LC - Livskraftig/LC - Livskraftig                          0.0
#
#    vitenskapelig_navn  vitenskapelig_navn_id
# 0    Zootoca vivipara                   1590
# 1  Anas platyrhynchos                   3461
# 2         Anser anser                   3471
# 3     Aythya fuligula                   3487
# 4  Bucephala clangula                   3501
#
# [5 rows x 34 columns]

# %%
AV = AV.rename(columns={"RL_status":"Rødlistestatus",'prioritert':'Kriterium_Prioriterte_arter','freda':"Kriterium_Fredete_arter","spesielle_oekologiske_former":"Kriterium_Spesielle_okologiske_former"})

# %%
# for arter som ikke har noen vurdering, slik som priorirterte (under)arter
AV.loc[AV["Vurderingsområde"].isna(),"Vurderingsområde"]="Norge"

# %%
# Identifisere ansvarsarter
AV.loc[AV["Andel av europeisk populasjon i Norge"].isna(),"Andel av europeisk populasjon i Norge"]="-"
AV.loc[AV["Andel av europeisk populasjon i Norge"].str.contains("50"), "Kriterium_Ansvarsart"] = "1"

# %%
# Remove potential 0's,
# replace potential X's with 1's
AV.loc[:, AV.columns.str.startswith('Kriterium_')] = AV.loc[:, AV.columns.str.startswith('Kriterium_')].replace({0: np.nan, 'X': 1})

# %% [markdown]
# # Arter av nasjonal forvaltningsinteresse

# %%
ANF = AV.loc[(AV["Rødlistestatus"].isin(["NT", "DD", "VU", "CR", "EN"])) | (~AV["Hensynskrevende"].isna()) | (AV["Kriterium_Ansvarsart"]=="X")
             | (AV["Risikokategori 2023"].isin(['SE', 'HI'])) | (AV["Forvaltningsverdi"].isin(["Svært stor verdi", "Stor verdi", "Middels verdi"]))]
ANF = ANF.loc[ANF["Vurderingsområde"].str.contains("Norge")] #Begrenser til fastlandsnorge

ANF = ANF[["vitenskapelig_navn_id", "Artsgruppe", "vitenskapelig_navn", "Populærnavn", "Rødlistestatus","Forvaltningsverdi", "Kriterium_Prioriterte_arter", "Kriterium_Fredete_arter", "Kriterium_kritisk trua art", "Kriterium_sterkt trua art", "Kriterium_sårbar art",	"Kriterium_Andre spesielt_hensynskrevende_arter", "Kriterium_Spesielle_okologiske_former", "Kriterium_NT", "Kriterium_DD", "Kriterium_Hensynskrevende_arter","Kriterium_Ansvarsart","Kriterium_Fremmede_arter"]]
ANF.columns = ANF.columns.str.replace(" ","_")
ANF.columns = ANF.columns.str.lower()
ANF.columns = ANF.columns.str.replace("æ","ae")
ANF.columns = ANF.columns.str.replace("ø","oe")
ANF.columns = ANF.columns.str.replace("å","aa")

# %%
ANF = ANF.sort_values("vitenskapelig_navn_id")
ANF = ANF.drop_duplicates()

# %%
# Export
ANF.to_csv('C:/data/ANF3.csv', index=False)
ANF.to_excel("C:/data/output.xlsx", index = False)
